# %% [markdown]
# # DLT pipeline
#
# This Delta Live Tables (DLT) definition is the entry point to the Framework.

# %%
import sys
from dlt_pipeline import DltPipelineBuilder

spark.conf.set("spark.databricks.sql.streamingTable.cdf.applyChanges.returnPhysicalCdf", True)

config = {
    "bundle_path": spark.conf.get("bundle.sourcePath", "."),
    "framework_path": spark.conf.get("framework.sourcePath", "."),
    "workspace_host": spark.conf.get("workspace.host", "."),
    "pipeline_name": spark.conf.get("pipeline.name", "."),
    "log_level": spark.conf.get("logLevel", "DEBUG")
}

sys.path.append(config["framework_path"])
DltPipelineBuilder(spark, dbutils, config)
# Out:
# Running cells with 'Python 3.9.6' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
