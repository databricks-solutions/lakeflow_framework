# %% [markdown]
# # Reset to Day 1
#
# Clears the **incremental** landing zone (day-2 / day-3 batches) while leaving the **initial**
# day-1 sample data in place. After running this, trigger **1 - Run 1 - Full Refresh** to
# reprocess the day-1 baseline only — no need to re-stage the initial TPC-H sample.

# %%
# %run ./initialize

# %%
reset_incremental()
