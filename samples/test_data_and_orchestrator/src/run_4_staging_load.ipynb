# %% [markdown]
# # Run 3 Load

# %%
# %run "./initialize"

# %%
spark.sql(f"""INSERT INTO TABLE {staging_schema}.customer (
  CUSTOMER_ID,
  FIRST_NAME,
  LAST_NAME,
  EMAIL,
  DELETE_FLAG,
  LOAD_TIMESTAMP)
VALUES
  (1, 'John', 'Doe', 'john.doe@another.example.com', False, '2023-01-04 10:00:00')""")
